# %% [markdown]
# # Preparation

# %%
import os

import numpy as np
import pandas as pd
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
pd.options.plotting.backend = 'matplotlib'

# import plotly.io as pio
# import plotly.express as px
# pio.templates.default = "plotly_white" # "plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"

# import seaborn as sns
# sns.set_style("whitegrid", {"axes.facecolor": ".9"})

import matplotlib.pyplot as plt
# plt.rcParams['text.usetex'] = True

# %matplotlib inline

# %% [markdown]
# # Data Schema

# %%
from sqlalchemy import create_engine

# Replace the placeholders with your actual AACT database credentials
# database_url = "postgresql://username:password@host:port/aact"

# Create a connection to the AACT database
engine = create_engine(database_url)

# %%
query = "SELECT * FROM studies LIMIT 1000"
df = pd.read_sql_query(query, con=engine)
df.head()
# Out:
#         nct_id nlm_download_date_description study_first_submitted_date  \
# 0  NCT01311856                          None                 2011-03-04
# 1  NCT01311869                          None                 2011-03-07
# 2  NCT01311882                          None                 2011-03-08
# 3  NCT01311908                          None                 2011-03-08
# 4  NCT01311921                          None                 2011-03-08
#
#   results_first_submitted_date disposition_first_submitted_date  \
# 0                         None                             None
# 1                         None                             None
# 2                         None                             None
# 3                         None                             None
# 4                         None                             None
#
#   last_update_submitted_date study_first_submitted_qc_date  \
# 0                 2019-05-16                    2011-03-08
# ...

# %%
query = "SELECT * FROM facilities LIMIT 1000"
df = pd.read_sql_query(query, con=engine)
df.head()
# Out:
#          id       nct_id status                               name  \
# 0  80542271  NCT00002509   None    Temple University Cancer Center
# 1  80542272  NCT00002510   None    Temple University Cancer Center
# 2  81101413  NCT00731432   None                    Herzog Hospital
# 3  81663820  NCT02097290   None  Glendale Adventist Medical Center
# 4  81101414  NCT00731445   None   The University of Tokyo Hospital
#
#            city         state    zip        country
# 0  Philadelphia  Pennsylvania  19140  United States
# 1  Philadelphia  Pennsylvania  19140  United States
# 2     Jerusalem          None  91035         Israel
# 3      Glendale    California  91204  United States
# 4         Tokyo          None   None          Japan

# %%
# The ClinicalTrials.gov database contains a wealth of information about ongoing and completed studies, including information about the study design, location, and contact information. To search for patient recruitment, several tables and fields within the database may be important, including:

# The studies table, which contains general information about each study, such as its official title, phase, and status.
# The facilities table, which contains information about the locations where the study is being conducted, including the facility's name, city, state, and country.
# The recruitment table, which contains information about the recruitment status of the study, including the estimated enrollment, inclusion and exclusion criteria, and contact information for the study site.
# Some specific fields that could be useful when searching for patient recruitment in the ClinicalTrials.gov database include:

# The nct_id field, which is a unique identifier for each study and could be used to link to other relevant tables in the database.
# The overall_status field, which indicates the current status of the study(e.g., "Recruiting", "Completed", "Withdrawn", etc.)
# The enrollment field in the recruitment table, which indicates the total number of participants currently enrolled in the study.
# The eligibility_criteria field in the recruitment table, which contains information about the inclusion and exclusion criteria for the study, such as the patient's age, sex, and disease stage.
# The study_contact field in the recruitment table, which contains contact information for the study site, such as the phone number and email address of the study coordinator.
# Additionally, you might want to use the conditions, interventions and location fields in the trials table to filter the data.
